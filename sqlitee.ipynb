# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['WARNING: Ignoring invalid distribution -atplotlib (c:\\users\\fatih emre\\anaconda3\\lib\\site-packages)',
#  'WARNING: Ignoring invalid distribution -atplotlib (c:\\users\\fatih emre\\anaconda3\\lib\\site-packages)',
#  'Requirement already satisfied: ipython-sql in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (0.5.0)',
#  'Requirement already satisfied: six in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (from ipython-sql) (1.16.0)',
#  'Requirement already satisfied: sqlalchemy>=2.0 in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (from ipython-sql) (2.0.29)',
#  'Requirement already satisfied: ipython in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (from ipython-sql) (8.2.0)',
#  'Requirement already satisfied: prettytable in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (from ipython-sql) (3.10.0)',
#  'Requirement already satisfied: sqlparse in c:\\users\\fatih emre\\anaconda3\\lib\\site-packages (from ipython-sql) (0.4.4)',
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite:///veritabanisql.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# MANUEL TABLO OLUŞTURMA

# %%
# %%sql
# CREATE TABLE yeni_tablomuz(firstname varchar(20),
#                           lastname varchar(20));
# Out:
#  * sqlite:///veritabanisql.db
# (sqlite3.OperationalError) table yeni_tablomuz already exists
# [SQL: CREATE TABLE yeni_tablomuz(firstname varchar(20),
#                           lastname varchar(20));]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# INSERT INTO yeni_tablomuz values('Ali', 'Uzaya_Git');
# Out:
#  * sqlite:///veritabanisql.db
# (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO yeni_tablomuz values('Ali', 'Uzaya_Git');]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT * FROM yeni_tablomuz LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Ali', 'Uzaya_Git'), ('Işık', 'Süte_Devam')]

# %%
# %%sql
# INSERT INTO yeni_tablomuz values('Işık', 'Süte_Devam');
# Out:
#  * sqlite:///veritabanisql.db
# (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO yeni_tablomuz values('Işık', 'Süte_Devam');]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT * FROM yeni_tablomuz LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Ali', 'Uzaya_Git'), ('Işık', 'Süte_Devam')]

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
TABLOLARI ÇAĞIRMAK İÇİN AŞAĞIDAKİ KOD:

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablomuz',),
#  ('Products',)]

# %%
BİR TABLODAKİ TÜM DEĞİŞKENLERİ ÇAĞIRMAK İÇİN:

# %%
# %%sql
# SELECT * FROM Customers WHERE 1=0;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
TABLODAKİ BİRKAÇ DEĞİŞKENİ ÇEKMEK İÇİN;

# %%
# %%sql
# SELECT CustomerName, City, CustomerID FROM Customers LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Alfreds Futterkiste', 'Berlin', 1),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.', 2),
#  ('Antonio Moreno Taquería', 'México D.F.', 3)]

# %% [markdown]
# #SQL İLE MATEMATİKSEL İŞLEM YAPMA:

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT Price, Price*2 from Products LIMIT 5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(18, 36), (19, 38), (10, 20), (22, 44), (21, 42)]

# %%
# %%sql
# SELECT Price, Price*3, Price*3-100 from Products LIMIT 5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(18, 54, -46), (19, 57, -43), (10, 30, -70), (22, 66, -34), (21, 63, -37)]

# %%
#alias: takma isim, kısayol

# %%
# %%sql
# SELECT Price AS Fiyat, Price*3 AS Fiyatx3, Price*3-100 AS islemli_price from Products LIMIT 5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(18, 54, -46), (19, 57, -43), (10, 30, -70), (22, 66, -34), (21, 63, -37)]

# %%
#count - kaç müşteri var ?

# %%
# %%sql
# SELECT COUNT(*) FROM Customers;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(91,)]

# %%
# %%sql
# SELECT COUNT(*) AS Müşteri_Sayisi FROM Customers;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(91,)]

# %%
#Order By, sıralama için

# %%
# %%sql
# SELECT * FROM Products ORDER BY Price LIMIT 15;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14),
#  (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15)]

# %%
#Büyükten küçüğe yapmak istersek;

# %%
# %%sql
# SELECT * FROM Products ORDER BY Price DESC LIMIT 15;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46),
#  (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45),
#  (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 45),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 43),
#  (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 43)]

# %% [raw]
# WHERE

# %%
# %%sql
# SELECT *FROM Customers LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# SELECT *FROM Customers WHERE City="Berlin";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')]

# %%
# %%sql
# SELECT *FROM Customers WHERE NOT City="Berlin" LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
# %%sql
# SELECT *FROM Customers WHERE CustomerID=5;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')]

# %%
#Numerik/Sayısal Seçim

# %%
# %%sql
# SELECT *FROM Customers WHERE PostalCode > 5021;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
#And ve Or İfadeleri

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="UK" and City="Cowes";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')]

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="UK" OR Country="USA";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="USA" AND (City="Albuquerque" OR City="Portland");
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')]

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="USA" AND PostalCode=87110 AND (City="Albuquerque" OR City="Portland");
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')]

# %%
#in not in kullanımı

# %%
# %%sql
# SELECT *FROM Customers WHERE CustomerID in (1,3,5,7)
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="USA" AND City in("Albuquerque","Portland");
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')]

# %%
# %%sql
#
# SELECT *FROM Customers WHERE CustomerID NOT IN (1,3,5,7)
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (12, 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
# ...

# %%
# %%sql
# SELECT *FROM Customers WHERE Country="USA" AND City NOT in("Albuquerque","Portland");
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (78, 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA'),
#  (82, "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA'),
# ...

# %%
# %%sql
# SELECT *FROM Customers LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
#müşteri adlarının ortasında or olan müşterileri bana getir

# %%
# %%sql
# SELECT *FROM Customers WHERE CustomerName LIKE "%or%" LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
# A İle biten isimleri getirmek için ise altta:

# %%
# %%sql
# SELECT *FROM Customers WHERE CustomerName LIKE "%a" LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')]

# %%
#a ile başlayan müşteri adlarını ve o ile biten ülkeleri bana getir;

# %%
# %%sql
# SELECT *FROM Customers WHERE CustomerName LIKE "a%" AND Country LIKE "%o";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#sql ile between

# %%
# %%sql
# SELECT *FROM Products LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
#Price 10-20 aralığını getirme

# %%
# %%sql
# SELECT *FROM Products WHERE Price BETWEEN 10 AND 20 LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18)]

# %%
#Price 10-20 aralığında olmayanları bulmak için ise;

# %%
# %%sql
# SELECT *FROM Products WHERE Price NOT BETWEEN 10 AND 20 LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6)]

# %%
#Fiyatı 10-20 arasında olsun ama kategorisi 1-2-3 olmasın

# %%
# %%sql
# SELECT *FROM Products WHERE (Price BETWEEN 10 AND 20) AND NOT CategoryID IN(1,2,3) LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (54, 'Tourtière', 25, 6, '16 pies', 16),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10)]

# %%
#Fiyatı 10-20 arasında olsun ama kategorisi 1-2-3 olmasın ve bunların sadece product name'ini getir.

# %%
# %%sql
# SELECT ProductName FROM Products WHERE (Price BETWEEN 10 AND 20) AND NOT CategoryID IN(1,2,3) LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Inlagd Sill',),
#  ('Singaporean Hokkien Fried Mee',),
#  ('Spegesild',),
#  ('Tourtière',),
#  ('Escargots de Bourgogne',),
#  ('Röd Kaviar',),
#  ('Longlife Tofu',)]

# %%
# %%sql
# SELECT *FROM Products WHERE ProductName BETWEEN "Carnarvon Tigers" AND "Mozarella di Govanni";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (13, 'Konbu', 6, 8, '2 kg box', 6),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21),
#  (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 43),
#  (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31),
#  (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32),
#  (33, 'Geitost', 15, 4, '500 g', 43),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
# ...

# %%
#Aggregation Fonksiyonları: Temel İstatisitksel İşlemler

# %%
# %%sql
# SELECT *FROM Products LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# SELECT MIN(Price) From Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(6,)]

# %%
# %%sql
# SELECT MAX(Price) From Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(435,)]

# %%
# %%sql
# SELECT MIN(Price) AS min_fiyat, MAX(Price) AS max_fiyat From Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(6, 435)]

# %%
#ortalama için ise;

# %%
# %%sql
# SELECT AVG(Price) From Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(39.15584415584416,)]

# %%
#Toplama için

# %%
# %%sql
# SELECT SUM(Price) From Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3015,)]

# %%
# %%sql
# SELECT COUNT(Price), MIN(Price), MAX(Price), (AVG(Price)), SUM(Price) FROM Products;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(77, 6, 435, 39.15584415584416, 3015)]

# %% [raw]
# GROUPBY VE AGGREGATİON FONKSİYONLARI

# %%
# %%sql
# SELECT *FROM Customers LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT COUNT(CustomerId) AS MUSTERI_SAYISI, Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT COUNT(CustomerName), Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT COUNT(CustomerId) AS MUSTERI_SAYISI, Country FROM Customers GROUP BY Country ORDER BY MUSTERI_SAYISI DESC;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# %%sql
# SELECT *FROM Products LIMIT 4;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22)]

# %%
# %%sql
# SELECT CategoryID, AVG(Price) AS AveragePrice FROM Products GROUP BY CategoryID ORDER BY AveragePrice DESC;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(4, 74.9),
#  (6, 55.166666666666664),
#  (1, 42.75),
#  (3, 33.76923076923077),
#  (7, 32.2),
#  (2, 28.25),
#  (8, 26.5),
#  (5, 23.571428571428573)]

# %% [raw]
# JOİN İŞLEMLERİ

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type="table";
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablomuz',),
#  ('Products',)]

# %%
# %%sql
# SELECT *FROM Categories LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT *FROM Products LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
#leftjoin soldaki tablo değerleriyle kesişen sağdaki tabloyu bir araya getirir.

# %%
# %%sql
# SELECT * FROM Products LEFT OUTER JOIN Categories ON Products.CategoryID = Categories.CategoryID LIMIT 6;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
# %%sql
# SELECT Products.ProductName, Categories.CategoryID, Categories.CategoryName FROM Products LEFT OUTER JOIN Categories ON Products.CategoryID = Categories.CategoryID LIMIT 6;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments'),
#  ("Grandma's Boysenberry Spread", 2, 'Condiments')]

# %%
AYNISI ALTTA KISALTILMIŞI ÖĞREN
# Out:
#   Input In [51]
#     AYNISI ALTTA KISALTILMIŞI ÖĞREN
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
# SELECT PR.ProductName, CA.CategoryID, CA.CategoryName FROM Products AS PR LEFT OUTER JOIN Categories AS CA ON PR.CategoryID = CA.CategoryID LIMIT 6;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments'),
#  ("Grandma's Boysenberry Spread", 2, 'Condiments')]

# %% [raw]
# INNER JOİN

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Orders LIMIT 3;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# %%sql
# SELECT Orders.OrderId, Customers.CustomerName FROM Orders INNER JOIN Customers ON Orders.CustomerID = Customers.CustomerID LIMIT 10;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(10248, 'Wilman Kala'),
#  (10249, 'Tradição Hipermercados'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprêmes délices'),
#  (10253, 'Hanari Carnes'),
#  (10254, 'Chop-suey Chinese'),
#  (10255, 'Richter Supermarkt'),
#  (10256, 'Wellington Importadora'),
#  (10257, 'HILARIÓN-Abastos')]

# %%
# %%sql
# SELECT COUNT(*) FROM (SELECT Orders.OrderId, Customers.CustomerName FROM Orders INNER JOIN Customers ON Orders.CustomerID = Customers.CustomerID);
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(196,)]

# %% [raw]
# SQL VE PANDAS DATAFRAME OPERASYONLARI

# %%
import pandas as pd

# %%
# %%sql
# SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, COUNTRY FROM Customers GROUP BY Country ORDER BY MUSTERI_SAYISI DESC;
# Out:
#  * sqlite:///veritabanisql.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
df= %sql SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, COUNTRY FROM Customers GROUP BY Country ORDER BY MUSTERI_SAYISI DESC;
# Out:
#  * sqlite:///veritabanisql.db
# Done.

# %%
df
# Out:
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
dff = pd.DataFrame(df, columns = ["MUS_SAYISI", "ULKE"])

# %%
dff.head()
# Out:
#    MUS_SAYISI     ULKE
# 0          13      USA
# 1          11  Germany
# 2          11   France
# 3           9   Brazil
# 4           7       UK

# %%
pip install --upgrade --force-reinstall matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.4-cp39-cp39-win_amd64.whl (7.7 MB)
# ...
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\fatih emre\anaconda3\lib\site-packages)
# ...

# %%
import matplotlib.pyplot as plt

# Assuming dff is your DataFrame
plt.barh(dff["ULKE"], dff["MUS_SAYISI"])
plt.xlabel("MUS_SAYISI")
plt.ylabel("ULKE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 import matplotlib.pyplot as plt
#       3 # Assuming dff is your DataFrame
#       4 plt.barh(dff["ULKE"], dff["MUS_SAYISI"])
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:109, in <module>
#     105 from packaging.version import parse as parse_version
#     107 # cbook must import matplotlib only within function
#     108 # definitions, so it is safe to import from it here.
# --> 109 from . import _api, _version, cbook, docstring, rcsetup
#     110 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     111 from matplotlib.cbook import mplDeprecation  # deprecated
#
# File ~\anaconda3\lib\site-packages\matplotlib\rcsetup.py:27, in <module>
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ...

# %% [raw]
# sqlite3

# %%
import sqlite3

# %%
conn = sqlite3.connect("vbo.db")

# %%
# ?conn
# Out:
# Call signature: conn(*args, **kwargs)
# Type:           Connection
# String form:    <sqlite3.Connection object at 0x0000019596E06A80>
# File:           c:\users\fatih emre\anaconda3\lib\sqlite3\__init__.py
# Docstring:      SQLite database connection object.

# %%
c = conn.cursor()

# %%
# ?c
# Out:
# Type:        Cursor
# String form: <sqlite3.Cursor object at 0x0000019596E72960>
# File:        c:\users\fatih emre\anaconda3\lib\sqlite3\__init__.py
# Docstring:   SQLite database cursor class.

# %%
import pandas as pd

# %%
pd.read_sql?
# Out:
# Signature:
# pd.read_sql(
#     sql,
#     con,
#     index_col: 'str | Sequence[str] | None' = None,
#     coerce_float: 'bool' = True,
#     params=None,
#     parse_dates=None,
#     columns=None,
#     chunksize: 'int | None' = None,
# ) -> 'DataFrame | Iterator[DataFrame]'
# Docstring:
# Read SQL query or database table into a DataFrame.
#
# This function is a convenience wrapper around ``read_sql_table`` and
# ``read_sql_query`` (for backward compatibility). It will delegate
# to the specific function depending on the provided input. A SQL query
# will be routed to ``read_sql_query``, while a database table name will
# be routed to ``read_sql_table``. Note that the delegated function might
# have more specific notes about their functionality not listed here.
#
# Parameters
# ----------
# sql : str or SQLAlchemy Selectable (select or text object)
#     SQL query to be executed or a table name.
# con : SQLAlchemy connectable, str, or sqlite3 connection
# ...

# %%
pd.read_sql("SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, Country FROM Customers GROUP BY Country;", conn)
# Out:
#     MUSTERI_SAYISI      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
ab = pd.read_sql("SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, Country FROM Customers GROUP BY Country;", conn)

# %%
ab
# Out:
#     MUSTERI_SAYISI      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
type(ab)
# Out:
# pandas.core.frame.DataFrame

# %%
c.execute("SELECT CustomerName FROM Customers LIMIT 5")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("SELECT CustomerName FROM Customers LIMIT 5;"):
                      print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)

# %% [markdown]
# SQL ÖDEVİ - 1

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [raw]
# 1. ORDERS TABLOSUNDA KAÇ MÜŞTERİ OLDUĞUNU BULUNUZ.

# %%
# %%sql
# SELECT * FROM ORDERS LIMIT 3;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# %%sql
# SELECT COUNT(CustomerID) FROM ORDERS;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(196,)]

# %% [markdown]
# 2. ORDERS TABLOSUNDA KAÇ TANE UNİQUE MÜŞTERİ OLDUĞUNU BULUNUZ.

# %%
# %%sql
# SELECT COUNT(DISTINCT CustomerID) FROM ORDERS;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(74,)]

# %% [markdown]
# 3.CUSTOMERS TABLOSUNDA HANGİ ÜLKEDEN KAÇAR MÜŞTERİ OLDUĞUNU BULUNUZ

# %%
# %%sql
# SELECT Country, COUNT(*) AS MUSTERI_SAYISI FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Argentina', 3),
#  ('Austria', 2),
#  ('Belgium', 2),
#  ('Brazil', 9),
#  ('Canada', 3),
#  ('Denmark', 2),
#  ('Finland', 2),
#  ('France', 11),
#  ('Germany', 11),
#  ('Ireland', 1),
#  ('Italy', 3),
#  ('Mexico', 5),
#  ('Norway', 1),
#  ('Poland', 1),
#  ('Portugal', 2),
#  ('Spain', 5),
#  ('Sweden', 2),
#  ('Switzerland', 2),
#  ('UK', 7),
#  ('USA', 13),
#  ('Venezuela', 4)]

# %% [markdown]
# 4.MÜŞTERİLERİN ÜLKESİ BRAZİL VEYA USA OLANLARINI BULUNUZ.

# %%
# %%sql
# SELECT * FROM Customers WHERE Country IN ("Brazil", "USA");
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %% [markdown]
# 5.ÖNCE ÜLKEYE SONRA ŞEHRE GÖRE GROUPBY İŞLEMİ YAPIP BU KIRILIMDA MÜŞTERİ SAYISINI BULUNUZ.

# %%
# %%sql
# SELECT Country, City, COUNT(*) AS MÜŞTERİ_SAYİSİ FROM Customers GROUP BY Country, City;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Argentina', 'Buenos Aires', 3),
#  ('Austria', 'Graz', 1),
#  ('Austria', 'Salzburg', 1),
#  ('Belgium', 'Bruxelles', 1),
#  ('Belgium', 'Charleroi', 1),
#  ('Brazil', 'Campinas', 1),
#  ('Brazil', 'Resende', 1),
#  ('Brazil', 'Rio de Janeiro', 3),
#  ('Brazil', 'São Paulo', 4),
#  ('Canada', 'Montréal', 1),
#  ('Canada', 'Tsawassen', 1),
#  ('Canada', 'Vancouver', 1),
#  ('Denmark', 'København', 1),
#  ('Denmark', 'Århus', 1),
#  ('Finland', 'Helsinki', 1),
#  ('Finland', 'Oulu', 1),
#  ('France', 'Lille', 1),
#  ('France', 'Lyon', 1),
#  ('France', 'Marseille', 1),
#  ('France', 'Nantes', 2),
#  ('France', 'Paris', 2),
#  ('France', 'Reims', 1),
#  ('France', 'Strasbourg', 1),
#  ('France', 'Toulouse', 1),
#  ('France', 'Versailles', 1),
#  ('Germany', 'Aachen', 1),
#  ('Germany', 'Berlin', 1),
#  ('Germany', 'Brandenburg', 1),
#  ('Germany', 'Cunewalde', 1),
#  ('Germany', 'Frankfurt a.M.', 1),
# ...

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# SQL ALIŞTIRMASI 2

# %% [markdown]
# 6.MÜŞTERİLERİ ADRESLERİNİN HERHANGİ BİR YERİNDE "DA" İFADESİ GEÇEN TÜM ADRESLERİ BULUNUZ

# %%
# %%sql
# SELECT * FROM Customers WHERE Address LIKE "%da%";
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
# ...

# %% [markdown]
# 7.GERMANY-BERLİNDE YAŞAYAN MÜŞTERİ/MÜŞTERİLERİN İSMİ NEDİR ?

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE Country ="Germany" AND City="Berlin";
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Alfreds Futterkiste',)]

# %% [markdown]
# 8.Canadada YAŞAYIP İSİMLERİNDE "in" İFADESİ GEÇEN MÜŞTERİ/MÜŞTERİLERİ BULUNUZ.

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE CustomerName LIKE '%in%' AND Country = 'Canada';
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Laughing Bacchus Wine Cellars',)]

# %% [markdown]
# 9.FİYATI 40 TL İLE 90 TL ARASINDA OLAN ÜRÜNLERİN İSİMLERİ VE FİYATLARI NELERDİR ?

# %%
# %%sql
# SELECT ProductName, Price From Products WHERE Price <=90 And Price >=40;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Northwoods Cranberry Sauce', 40),
#  ('Genen Shouyu', 43),
#  ('Carnarvon Tigers', 62),
#  ('Teatime Chocolate Biscuits', 43),
#  ("Sir Rodney's Marmalade", 81),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Rössle Sauerkraut', 45),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Ipoh Coffee', 46),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Manjimup Dried Apples', 53),
#  ('Ravioli Angelo', 43),
#  ('Raclette Courdavault', 55),
#  ("Sirop d'érable", 43),
#  ('Tarte au sucre', 49),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43),
#  ('Scottish Longbreads', 45)]

# %% [markdown]
# 10.FİYATI 30 TLdEN BÜYÜK OLAN ÜRÜNLERİN İSİMLERİNİ, FİYATLARINI VE FİYATLARINI KARESİNİ BULUNUZ VE TÜM DEĞİŞKENLERİNİN İSİMLERİNİ AŞAĞIDAKİ ŞEKİLDE YAPINIZ.: urun ismi, urun_fiyati, ürün_fiyatinin_karesi;

# %%
# %%sql
# SELECT ProductName as urun_ismi, Price AS urun_fiyati, Price*Price AS urunfiyatinin_karesi From Products WHERE Price >=30;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [("Uncle Bob's Organic Dried Pears", 30, 900),
#  ('Northwoods Cranberry Sauce', 40, 1600),
#  ('Mishi Kobe Niku', 97, 9409),
#  ('Ikura', 31, 961),
#  ('Queso Manchego La Pastora', 38, 1444),
#  ('Genen Shouyu', 43, 1849),
#  ('Alice Mutton', 39, 1521),
#  ('Carnarvon Tigers', 62, 3844),
#  ('Teatime Chocolate Biscuits', 43, 1849),
#  ("Sir Rodney's Marmalade", 81, 6561),
#  ('Guaraná Fantástica', 43, 1849),
#  ('Gumbär Gummibärchen', 31, 961),
#  ('Schoggi Schokolade', 43, 1849),
#  ('Rössle Sauerkraut', 45, 2025),
#  ('Thüringer Rostbratwurst', 123, 15129),
#  ('Gorgonzola Telino', 435, 189225),
#  ('Mascarpone Fabioli', 32, 1024),
#  ('Geitost', 43, 1849),
#  ('Côte de Blaye', 263, 69169),
#  ('Boston Crab Meat', 43, 1849),
#  ('Ipoh Coffee', 46, 2116),
#  ('Røgede sild', 43, 1849),
#  ('Zaanse koeken', 43, 1849),
#  ('Manjimup Dried Apples', 53, 2809),
#  ('Perth Pasties', 32, 1024),
# ...

# %%
# %%sql
# SELECT *FROM Categories LIMIT 3;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT *FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %% [markdown]
# SQL ALIŞTIRMALARI 3

# %% [markdown]
# 11.Products Tablosundaki category_idlerin yani kategorilerin isimleri nelerdir ?

# %%
# %%sql
# SELECT *
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 7, 'Produce', 'Dried fruit and bean curd'),
# ...

# %% [markdown]
# 12.Beverages Ürün kategorisindeki ürünlerin fiyat ortalaması nedir ?

# %%
# %%sql
# SELECT AVG(Price)
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = categories.CategoryID
# WHERE CategoryName = 'Beverages';
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(42.75,)]

# %% [markdown]
# 13.USADA YAŞAYAN MÜŞTERİLERİN KAZANDIRDIĞI TOPLAM KAZANCI BULUNUZ.

# %%
# %%sql
# SELECT SUM(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(3762,)]

# %% [markdown]
# 14.PRODUCT TABLOSUNDAKİ CATEGORY_İDLERİN İSİMLERİNİ BULUNUZ VE SONRASINDA KATEGORİ BAŞINA ORTALAMA ÜRÜN FİYATINI GÖSTERİNİZ.

# %%
# %%sql
# SELECT AVG(Price), CategoryName
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID
# GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(42.75, 'Beverages'),
#  (28.25, 'Condiments'),
#  (33.76923076923077, 'Confections'),
#  (74.9, 'Dairy Products'),
#  (23.571428571428573, 'Grains/Cereals'),
#  (55.166666666666664, 'Meat/Poultry'),
#  (32.2, 'Produce'),
#  (26.5, 'Seafood')]

# %% [markdown]
# 15.ÇALIŞANLARI(EMPOLYEE) İSİMLERİ İLE BİRLİKTE YAPTIKARI TOPLAM SATIŞLARA GÖRE SIRALAYINIZ.

# %%
# %%sql
# SELECT em.FirstName, SUM(p.Price) toplam_satis
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Employees em on o.EmployeeID = em.EmployeeID
# GROUP BY o.EmployeeID
# ORDER BY toplam_satis DESC;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Margaret', 5515),
#  ('Nancy', 4353),
#  ('Janet', 3048),
#  ('Michael', 2981),
#  ('Laura', 2380),
#  ('Robert', 1852),
#  ('Andrew', 1550),
#  ('Steven', 1408),
#  ('Anne', 520)]

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT * FROM Customers LIMIT 5;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 5;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal')]

# %% [markdown]
# SQL 4. ÇALIŞMA

# %% [markdown]
# 16.ALMANYADAN VERİLEN SİPARİŞLERİN KATEGORİLERİNE GÖRE ORTALAMA FİYATLAR NELERDİR ?

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Beverages', 20.5),
#  ('Condiments', 34.0),
#  ('Confections', 40.0),
#  ('Dairy Products', 151.64705882352942),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Meat/Poultry', 30.2),
#  ('Produce', 30.75),
#  ('Seafood', 27.09090909090909)]

# %% [markdown]
# 17.ALMANYA YA DA USADEN VERİLEN SİPARİŞLERİN KATEGORİLERİNE GÖRE ORTALAMA FİYATLARI NELERDİR ?

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' OR cu.Country="USA" GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %% [markdown]
# 18.HAZİRAN TEMMUZ AĞUSTOS AYLARINDA VERİLEN SİPARİŞLERİN ORTALAMA FİYATI NEDİR ?

# %%
# %%sql
# SELECT AVG(Products.Price)
# FROM Products
# LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(39.71891891891892,)]

# %% [markdown]
# 19.MÜŞTERİLERİN 1997 YILINA AİT SİPARİŞLERİNİN MAKSİMUM MİKTARINI BULUP MÜŞTERİLERİN İSİMLERİ İLE BİRLİKTE BÜYÜKTEN KÜÇÜĞE SIRALAYINIZ.

# %%
# %%sql
# SELECT CustomerName, MAX(Price) maks
# FROM Products
# LEFT JOIN OrderDetails on Products.ProductID = OrderDetails.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# LEFT JOIN Customers on Customers.CustomerID = Orders.CustomerID
# WHERE OrderDate like '%1997%'
# GROUP BY CustomerName ORDER BY maks DESC;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [('Gourmet Lanchonetes', 435),
#  ('Simons bistro', 263),
#  ('Mère Paillarde', 263),
#  ('Save-a-lot Markets', 123),
#  ('Eastern Connection', 123),
#  ('Wellington Importadora', 97),
#  ('Ernst Handel', 55),
#  ('Bottom-Dollar Marketse', 55),
#  ("La maison d'Asie", 49),
#  ('Folies gourmandes', 49),
#  ('Reggiani Caseifici', 45),
#  ('Queen Cozinha', 45),
#  ('Wartian Herkku', 43),
#  ('Toms Spezialitäten', 43),
#  ('Rattlesnake Canyon Grocery', 43),
#  ('Que Delícia', 43),
#  ('QUICK-Stop', 43),
#  ('Old World Delicatessen', 43),
#  ('Hungry Owl All-Night Grocers', 43),
#  ('Hungry Coyote Import Store', 43),
#  ('Familia Arquibaldo', 43),
#  ('Princesa Isabel Vinhoss', 38),
#  ('Galería del gastrónomo', 38),
#  ('Blondel père et fils', 38),
#  ('Richter Supermarkt', 36),
#  ('Ottilies Käseladen', 36),
#  ('Consolidated Holdings', 34),
#  ('Split Rail Beer & Ale', 31),
#  ('Magazzini Alimentari Riuniti', 31),
# ...

# %% [markdown]
# 20.SİPARİŞ YILI 1997 OLAN SİPARİŞLERİ ALAN ÇALIŞANLARI SİPARİŞ ALMA SAYILARINA GÖRE SIRALAYINIZ.

# %%
# %%sql
# SELECT COUNT(*) n, em.FirstName
# FROM Orders
# LEFT JOIN Employees em on Orders.EmployeeID = em.EmployeeID
# WHERE OrderDate like '%1997%'
# GROUP BY em.FirstName
# ORDER by n DESC;
# Out:
#  * sqlite:///vbo.db
#    sqlite:///veritabanisql.db
# Done.
# [(13, 'Janet'),
#  (9, 'Margaret'),
#  (8, 'Laura'),
#  (4, 'Andrew'),
#  (3, 'Robert'),
#  (3, 'Nancy'),
#  (3, 'Michael'),
#  (1, 'Anne')]
